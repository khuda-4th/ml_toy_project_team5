# %%
# !pip install ultralytics
cls_names = {0: 'binch', 1: 'oreoblack', 2: 'oreored', 3: 'cushcush', 4: 'gosomi', 5: 'yegamcheese', 6: 'oreothinstaramisu', 7: 'oreothinsvanillamooth', 8: 'chocchochanchocochip', 9: 'chicchoc', 10: 'yuginongblueberrytt', 11: 'yuginongaroniatt', 12: 'yuginongsiguemchitt', 13: 'yuginongbananatt', 14: 'yuginongplaneyogurtcube', 15: 'yuginongbluberryyogurtcube', 16: 'yuginongbananayogurtcube', 17: 'yuginongddalgiyogurtcube', 18: 'finggercheeseblueberry', 19: 'finggercheeseorigin', 20: 'ggobuk', 21: 'simpop', 22: 'cheetosr', 23: 'cheetosb', 24: 'cheetosy', 25: 'gamjasokb', 26: 'gamjatokb', 27: 'gamjatokg', 28: 'beksulgangryeokmilgaru', 29: 'beksulbakryeokmilgaru', 30: 'beksuljungryeokmilgaru', 31: 'beksulchalmilgaru', 32: 'beksulwooriddangwoorimealmilgaru', 33: 'beksulbuchimgaru', 34: 'beksultwigimgaru', 35: 'beksulbasakbuchimgaru', 36: 'beksulbasaktwigimgaru', 37: 'beksulchickentwigimgaru', 38: 'gompyomilgarujoongryukdamokjukyong', 39: 'gompyochaljinhaetmilgaru', 40: 'gompyobuchimgaru', 41: 'ottogitwigimgaru', 42: 'ottogippanggaru', 43: 'nonghyupguksan100%ssalbuchimgaru', 44: 'beksulmc&cheesekit', 45: 'beksulpancakemix', 46: 'beksulhotcakemix', 47: 'beksulyeongyanggyunhyeonghotcakemix', 48: 'beksulwoorimealhotcakemix', 49: 'beksulchocochiphotcakemix', 50: 'beksulchococakemix', 51: 'beksulsikppangmix', 52: 'beksuldonutmix', 53: 'beksulmuffinmix', 54: 'beksulbrowniemix', 55: 'beksulchapssalhotteokmix', 56: 'beksulnokchamatchapssalhotteokmix', 57: 'beksulinjeolmihotteokmix', 58: 'beksulchocochipcookiemix', 59: 'ottogichapssalhotteokmix', 60: 'ottogihotcakemix', 61: 'ottogissalhotcakemix', 62: 'ottogichoganpyeonkimchijeonmix', 63: 'damoolchamimatbakingpowder', 64: 'damoolchamimatnewsugar', 65: 'damoolsoda', 66: 'damoolgyepigaru', 67: 'qonehomemadeyungyangcookiemix', 68: 'qonehomemademuffinmix', 69: 'qonehomemadebrowniemix', 70: 'a1steaksauce', 71: 'ottogigosohanmayonnaise', 72: 'ottogifreshmayonnaise', 73: 'chungjungonechamkkaeheukimja', 74: 'ottogiwasabidressing', 75: 'ottogiorientaldressing', 76: 'fontanaoriental', 77: 'fontanazerofatgreenkiwi', 78: 'fontanazerofatpineapple', 79: 'ottogicaloriereuljurinketchup33%', 80: 'ottogijalapenoketchup', 81: 'srirachaketchup', 82: 'ottogigosohangoldmayonnaise', 83: 'chungjeongwonsweetcornmayosauce', 84: 'chungjeongwongarliccheesemayosauce', 85: 'ottogicoleslawdressing', 86: 'chungjeongwoncoleslawdressing', 87: 'homeplusthousandIslanddressing', 88: 'homepluskiwidressing', 89: 'homepluschamkkaedressing', 90: 'homeplushoneymustard', 91: 'homeplusbalsamicdressing', 92: 'sampioyeondoosoon', 93: 'chungjungonesoonchanggochujang', 94: 'chungjungonesoonchangchogochujang', 95: 'chungjungonesoonchangtaeyangchossalgochujang', 96: 
bibigokodarimujorim', 332: 'ottogimaekomkkongchijorim', 333: 'ottogipomodorokkongchijorim', 334: 'ottogikimchigodeungeojorim', 335: 'lottehamgochujanggogibokkeum', 336: 'lottehamjangjorim', 337: 'yorihadamiyeokguk', 338: 'yorihadahwangtaehaejangguk', 339: 'bibigogamjatang', 340: 'bibigochadoldoenjangjjigae', 341: 'bibigojeonbokmiyeokguk', 342: 'bibigojingukseolleongtang', 343: 'bibigodubukimchijjigae', 344: 'bibigodoenjangjjigae', 345: 'bibigobangyetang', 346: 'bibigokongnamulhwangtaeguk', 347: 'yorihadaeolkeunsoondaeguk', 348: 'yorihadakimchijjigae', 349: 'yorihadayukgaejang', 350: 'yorihadasagolgomtang', 351: 'yorihadayangjiyuksu', 352: 'yorihadasumgyetang', 353: 'yorihadasusambangyetang', 354: 'yangbanboyangsamgyetang', 355: 'yangbanhanwoosagolsiraegiguk', 356: 'yangbanaehobakgochujangjjigae', 357: 'yangbanjeonjusikhwangtaekongnamulguk', 358: 'yangbanugeojidoenjangguk', 359: 'dongwonganpyeonyorikitgolbaengibibimureonggangdoenjang', 360: 'dongwonganpyeonyorikitgolbaengimulhoe', 361: 'dongwonganpyeonyorikitgolbaengitangeolkeunhangungmul', 362: 'dongwonganpyeonyorikitureonggangdoenjang', 363: 'nongshimneogurimild', 364: 'nongshimneogurispicy', 365: 'nongshimneoguriangry', 366: 'nongshimgamjamyeon', 367: 'nongshimjjawang', 368: 'nongshimjjawangspicy', 369: 'nongshimdoongjinaengmyeonbibim', 370: 'nongshimdoongjinaengmyeondongchimi', 371: 'ottogijinramenmild', 372: 'ottogijinramenspicy', 373: 'yangbanchamchijuk', 374: 'yangbanyachaejuk', 375: 'yangbansogokijuk', 376: 'yangbandeulkkaedakjuk', 377: 'yangbanbaekhabjuk', 378: 'yangbandanhobakjuk', 379: 'yangbanbamdanpatjuk', 380: 'yangbanmiyeokjuk', 381: 'yangbanjeonbokjuk', 382: 'yangbanmpjeonbokjuk', 383: 'yangbanmpbaekhabjuk', 384: 'yangbansamgyejeonbokjuk'}

# %%
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
import cv2

# %%
model = YOLO('best.pt')
img = 'custom_image'
results = model.predict(img + '.jpg', save_txt=True)
# Out:
# image 1/1 /content/05-450.jpg: 352x608 3 simpops, 3 cheetosrs, 5 cheetosbs, 1 cheetosy, 416.9ms
# Speed: 3.6ms preprocess, 416.9ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 608)
# Results saved to runs/detect/predict11
# 1 label saved to runs/detect/predict11/labels

# %%
products_prices = {'cheetosb': 1300, 'cheetosr': 1300, 'cheetosy': 1300, 'simpop': 1200, 'gamjatokb': 1400, 'gamjatokg': 1400, 'ggobuk': 1100, 'ottogijinramenmild': 800}
dir = str(results[0]).split('\n')[-2].split("'")[1]
with open(dir + '/labels/{}.txt'.format(img)) as f:
    lines = f.readlines()
f.close()
count_result = {}
for line in lines:
    obj = int(line.split(' ')[0])
    if obj in count_result:
        count_result[obj] += 1
    else:
        count_result[obj] = 1

# %%
res_plotted = results[0].plot()
cv2_imshow(res_plotted)

total = 0
for product_code, count in count_result.items():
    name = cls_names[product_code]
    print('{}: {}개. (1개당 {}원)'.format(name, count, products_prices[name]))
    total += products_prices[name] * count
print('총 금액: {}원'.format(total))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
